# %% [markdown]
# ## Yaml介绍与安装

# %% [markdown]
# 在自动化测试领域，数据需要与代码分离。<br/>当代码与数据分离时，只需要更改分离的数据，不需要更改代码。(基于数据来驱动自动化测试的内容）平时选择数据驱动类型都是基于测试框架来定义的<br/>数据驱动一般分为两类：1.EXCEL   2.YAML

# %% [markdown]
# 用途：<br/>
# 1.用于配置文件 ：配置全局的数据：环境变量，数据库信息，账号信息，日志格式，日志报告名称,主要ini/yml<br/>**2.用于写测试用例（接口自动化测试用例）**<br/>3.能够展示各种数据类型

# %% [markdown]
# **规则**：<br/>
# 1、使用缩进表示层级关系<br/>
# 2、缩进空格数目不重要，只要相同层级的元素左对齐即可<br/>
# 3、大小写敏感<br/>
# 4、注意！在冒号之后需要有空格，否则语法报错<br/>

# %% [markdown]
# **数据组成：**<br/>1.Map对象：键值对&nbsp;键：空格+值
# <br/>2.数组（list）用一组-表示

# %% [markdown]
# **YAML和JSON数据结构对比**<br/>JSON<BR/>1.Map对象：键值对。（字典）<br/>2.数组（列表）<br/>使用[]括起来

# %% [markdown]
# YAML<BR/>1.Map对象：键值对（字典）<br/>格式差异：写法一： name: zhangsan<br/>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;写法二 ： name: {age: 1,sex: 1}

# %% [markdown]
# 写入列表：<br/>-  #顶格表示列表<br/>&nbsp;&nbsp;-1#缩进表示嵌套的列表<br/>&nbsp;&nbsp;-2<br/>-&nbsp;&nbsp;a<br/>-&nbsp;&nbsp;b
# ![image.png](attachment:image.png)

# %% [markdown]
# 写入字典：<br/>（直接编写，不需要加引号）![image-2.png](attachment:image-2.png)![image-3.png](attachment:image-3.png)

# %%
# 读取yaml文件
import yaml
class YamlUtil:
    def __init__(self,yaml_file):
        """通过init方法把yaml文件传入这个类
        :param yaml_file"""
        self.yaml_file=yaml_file
    #读取文件
    def read_yaml(self):
        """
        读取yaml，对yaml反序列化（将yaml格式转换为dict格式）
        :return:
        """
        with open(self.yaml_file,encoding="utf-8")as f:
            value=yaml.load(f,Loader=yaml.FullLoader)
            print(value,type(value))
if __name__ == '__main__':
    YamlUtil(r"E:\Python_home\py_test\api_testcase\test_api.yml").read_yaml()
# Out:
# {'mas': {'name': '百里', 'age': 18}} <class 'dict'>

# %% [markdown]
# YAML可以完美结合DDT进行使用

# %%
from ddt import ddt,file_data
import unittest
@ddt
class Demo(unittest.TestCase):
    @file_data("E:\python_code\Data\data1.yml")
    def test01(self,*args,**kwargs):
        print(args,kwargs)

# %% [markdown]
# ## yaml接口自动化实践
# 1.断言的封装<br/>2.allure报告的定制<br/>3.关键字驱动和数据驱动结合实现接口自动化测试<br/>4.python的反射<br/>5.通过Jenkins集成
